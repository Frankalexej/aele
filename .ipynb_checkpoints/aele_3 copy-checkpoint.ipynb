# %% [markdown]
# # Autoencoder Learning Experiment
# In this version, we try not to generate data based on real formants, but instead a toy data that roughly reflects the distribution but somewhat seems like the normalized version without being really normalized. This is mainly to tackle the problem of different ranges of variances for different formants, which should be tied to their specific means (larger value range, larger variance values)
#
# In version 3, we additionally compare the model with very little cross-phonemic contrast

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import calendar;
import time; # Importing necessary libraries
from sklearn.decomposition import PCA
from torch.utils.data import TensorDataset, DataLoader

from src.linear_ae_net.dynamics import *

# %% [markdown]
# ## Generate Dataset

# %%
def generate_gmm_data(d, n_components=4, random_state=42, num_data=1000, 
                            means=None, vars=None, sizes=None, tags=None):
    """
    Generate a GMM dataset with exact cluster sizes and custom string labels.

    - sizes: list of exact number of samples for each component; sum(sizes) == num_data
    - tags: list of string labels for each component

    Returns:
    - X: (num_data, d)
    - labels: (num_data,) array of strings (from tags)
    """
    rng = np.random.default_rng(random_state)

    if sizes is None:
        sizes = [num_data // n_components] * n_components
        sizes[-1] += num_data - sum(sizes)
    else:
        sizes = list(sizes)
        assert len(sizes) == n_components, "Sizes must match the number of components"
        num_data = sum(sizes)   # adjust num_data to match sizes

    if tags is None:
        tags = [str(i) for i in range(n_components)]
    else:
        assert len(tags) == n_components

    if means is None:
        means = rng.uniform(-20, 20, size=(n_components, d))
    else:
        means = np.array(means, dtype=float)
        assert means.shape == (n_components, d)

    if vars is None:
        covariances = [np.diag(rng.uniform(0.1, 0.2, size=d)) for _ in range(n_components)]
    else:
        covariances = [np.diag([var]*d) for var in vars]

    X = []
    labels = []
    for k in range(n_components):
        Xk = rng.multivariate_normal(means[k], covariances[k], size=sizes[k])
        X.append(Xk)
        labels.extend([tags[k]] * sizes[k])
    X = np.vstack(X)
    labels = np.array(labels)
    perm = rng.permutation(num_data)
    return X[perm], labels[perm]

def zscore_normalize(X):
    return (X - X.mean(axis=0)) / X.std(axis=0, ddof=0)

# %%
def plot_2d_projection_with_principal_axes(X, labels, dim_x=0, dim_y=1, label_names=None):
    """
    X: (N, d) array (d >= 2)
    labels: length-N int or string labels
    dim_x, dim_y: which dimensions to plot (0-based)
    label_names: list of label strings, or None to skip legend
    """
    # Map string labels to numeric for color
    label_names_unique, labels_numeric = np.unique(labels, return_inverse=True)
    
    # Compute mean and covariance in full space
    mu = X.mean(axis=0)
    C = np.cov(X, rowvar=False)
    U, S, Vt = np.linalg.svd(C)

    # 2D mean for plot
    mu2 = mu[[dim_x, dim_y]]

    plt.figure(figsize=(7, 7))
    # Scatterplot of projection
    plt.scatter(X[:, dim_x], X[:, dim_y], c=labels_numeric, alpha=0.6, cmap='tab10', label='')

    # Draw and label first two principal axes, projected
    for i in range(4):
        vec = U[:, i] * np.sqrt(S[i])
        vec2 = vec[[dim_x, dim_y]]
        plt.arrow(mu2[0], mu2[1], vec2[0], vec2[1], width=0.05, length_includes_head=True, label=f'σ{i+1}')
        plt.arrow(mu2[0], mu2[1], -vec2[0], -vec2[1], width=0.05, length_includes_head=True)
        plt.text(mu2[0] + vec2[0]*1.1, mu2[1] + vec2[1]*1.1, f'({i}){S[i]:.2f}', fontsize=12, fontweight='bold', ha='center', va='center')

    plt.xlabel(f"Dimension {dim_x+1}")
    plt.ylabel(f"Dimension {dim_y+1}")
    plt.title("GMM Samples: Principal Axes & Singular Values (Projected)")
    plt.grid(True)

    # Legend with class names, if available
    if label_names is not None:
        for i, name in enumerate(label_names_unique):
            plt.scatter([], [], c=[plt.cm.tab10(i)], label=name)
        plt.legend(title="Class")

    plt.show()

    # 1) Covariance matrix heatmap
    C = np.cov(X, rowvar=False)
    plt.figure()
    plt.imshow(C, aspect='equal')
    plt.colorbar()
    plt.title("Covariance Matrix")
    plt.xlabel("Dimension")
    plt.ylabel("Dimension")
    plt.show()

    # 2) Singular values
    U, S, Vt = np.linalg.svd(C)
    plt.figure()
    plt.bar(np.arange(1, len(S)+1), S)
    plt.xlabel("Component")
    plt.ylabel("Singular Value")
    plt.title("Singular Values of Covariance Matrix")
    plt.show()


def plot_2d_projection_with_principal_axes_2(X, labels, dim_x=0, dim_y=1, label_names=None):
    """
    X: (N, d) array (d >= 2)
    labels: length-N int or string labels
    dim_x, dim_y: which dimensions to plot (0-based)
    label_names: list of label strings, or None to skip legend
    """
    # Map string labels to numeric for color
    label_names_unique, labels_numeric = np.unique(labels, return_inverse=True)
    
    # Compute mean and covariance in full space
    mu = X.mean(axis=0)
    # C = np.cov(X, rowvar=False)
    C = compute_correlation_matrix(X, X)
    U, S, Vt = np.linalg.svd(C)

    # 2D mean for plot
    mu2 = mu[[dim_x, dim_y]]

    plt.figure(figsize=(7, 7))
    # Scatterplot of projection
    plt.scatter(X[:, dim_x], X[:, dim_y], c=labels_numeric, alpha=0.6, cmap='tab10', label='')

    # Draw and label first two principal axes, projected
    for i in range(4):
        vec = U[:, i] * np.sqrt(S[i])
        vec2 = vec[[dim_x, dim_y]]
        plt.arrow(mu2[0], mu2[1], vec2[0], vec2[1], width=0.05, length_includes_head=True, label=f'σ{i+1}')
        plt.arrow(mu2[0], mu2[1], -vec2[0], -vec2[1], width=0.05, length_includes_head=True)
        plt.text(mu2[0] + vec2[0]*1.1, mu2[1] + vec2[1]*1.1, f'{S[i]:.2f}', fontsize=12, fontweight='bold', ha='center', va='center')

    plt.xlabel(f"Dimension {dim_x+1}")
    plt.ylabel(f"Dimension {dim_y+1}")
    plt.title("GMM Samples: Principal Axes & Singular Values (Projected)")
    plt.grid(True)

    # Legend with class names, if available
    if label_names is not None:
        for i, name in enumerate(label_names_unique):
            plt.scatter([], [], c=[plt.cm.tab10(i)], label=name)
        plt.legend(title="Class")

    plt.show()

    # 1) Covariance matrix heatmap
    # C = np.cov(X, rowvar=False)
    C = compute_correlation_matrix(X, X)
    plt.figure()
    plt.imshow(C, aspect='equal')
    plt.colorbar()
    plt.title("Covariance Matrix")
    plt.xlabel("Dimension")
    plt.ylabel("Dimension")
    plt.show()

    # 2) Singular values
    U, S, Vt = np.linalg.svd(C)
    plt.figure()
    plt.bar(np.arange(1, len(S)+1), S)
    plt.xlabel("Component")
    plt.ylabel("Singular Value")
    plt.title("Singular Values of Covariance Matrix")
    plt.show()

# %% [markdown]
# ## Generate Both Training and Testing Data

# %% [markdown]
# ### Case 1: one contrast direction in training

# %%
# training means and shared std
means_train = [
    # np.array([120.0, 320.0, 1650.0, 2250.0]),  # /y/
    # np.array([120.0, 320.0,  800.0, 2250.0]),  # /u/
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
]
var_strength = 2.0  # Hz in all dimensions
vars_train = [var_strength, var_strength]
sizes_train = [500, 500]  # for example
tags_train = ["y", "u"]

means_test = [
    np.array([0.0, 5.0, -10.0, 0.0]),  # /ø/
    np.array([0.0, 5.0, 10.0, 0.0]),  # /o/
    np.array([0.0, 10.0, -10.0, 5.0]),  # /ɛ/
    np.array([0.0, 10.0, 10.0, 5.0]),  # /ʌ/
    np.array([0.0, 0.0, -10.0, 5.0]),  # /i/
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
]
vars_test = [var_strength] * len(means_test)
sizes_test = [50] * len(means_test)  # for example
tags_test = ["ø", "o", "ɛ", "ʌ", "i", "y", "u"]

data_train, labels_train = generate_gmm_data(d=4, n_components=len(tags_train), random_state=calendar.timegm(time.gmtime()), means=means_train, vars=vars_train, sizes=sizes_train, tags=tags_train)

data_test, labels_test = generate_gmm_data(d=4, n_components=len(tags_test), random_state=calendar.timegm(time.gmtime()) + 1, means=means_test, vars=vars_test, sizes=sizes_test, tags=tags_test)

# %% [markdown]
# ## Training

# %%
class LinearAutoEncoder():
    '''Neural network class'''
    def __init__(self):
        self.history = {'loss': [], 'val_loss': [], 'weights': {'W1':[], 'W2':[]}, 'activations': [], 'testing_activations': [], 'z_testing_activations': []}
    
    def train(self, X, X_val=None, input_dim=5, n_epoch=100, hidden_dim=100, learning_rate=0.1, reg_param=0.0001, 
              noise='gaussian', noise_scale=1, verbose=False, Y=None, Y_val=None, Z=None, Z_val=None):
        """
        Y: testing data
        """
        self.y_val = Y_val
        dtype = torch.cuda.FloatTensor
        X_in = X.clone().type(dtype)
        X = X.type(dtype)
        N = X.shape[0]
        D = X.shape[1]
        
        self.strenghts = torch.zeros((1, D)).type(dtype)
        self.W1 = 0.0001*torch.randn(X.shape[1], hidden_dim).type(dtype)
        self.W2 = 0.0001*torch.randn(hidden_dim, input_dim).type(dtype)

        W = self.W1.mm(self.W2)
        s_int = np.linalg.svd(W.cpu().numpy(), compute_uv=0)
        self.init = np.sum(s_int[:100])/len(s_int)

        corr_mat = compute_correlation_matrix(X.cpu().numpy(), X.cpu().numpy())
        self.U, self.S, self.Vt = np.linalg.svd(corr_mat)

        UZ = torch.from_numpy((Z.cpu().numpy() @ self.U.T)) if Z is not None else None
        
        for t in range(n_epoch):
            
            W1 = self.W1
            W2 = self.W2
            
            # compute scores
            h1 = X_in.mm(W1)
            scores = h1.mm(W2)

            # compute loss
            data_loss = 0.5*((scores - X).pow(2).sum())/N
            noise_loss = 0.5*noise_scale*torch.trace(W2.t().mm(W1.t()).mm(W1).mm(W2))
            reg_loss = 0.5*reg_param*torch.sum(W1*W1) + 0.5*reg_param*torch.sum(W2*W2)
            loss = data_loss + noise_loss + reg_loss
                    
            # store loss
            self.history['loss'].append(loss)
        
            # compute the gradient using backpropagation
            dscores = (scores - X)/N
            dW2 = h1.t().mm(dscores)
            dhidden = dscores.mm(W2.t())
            dW1 = X_in.t().mm(dhidden)
            
            # add regularisation gradients
            dW2 += reg_param*W2
            dW1 += reg_param*W1
            
            # add noise gradients
            dW1 += noise_scale*W1.mm(W2).mm(W2.t())
            dW2 += noise_scale*W1.t().mm(W1).mm(W2)

            # perform parameter updates
            self.W1 += -learning_rate*dW1
            self.W2 += -learning_rate*dW2
            
            # compute validation loss
            if X_val is not None:
                val_pred = self.predict(X_val)
                val_loss = 0.5*(X_val - val_pred).pow(2).sum()/N
                self.history['val_loss'].append(val_loss)
                if verbose:
                    if t % 100 == 0:
                        print('iteration: ', t, 'training loss: ', loss, ' validation loss: ', val_loss)
            else:
                if verbose:
                    if t % 100 == 0:
                        print('iteration: ', t, 'training loss: ', loss)
            
            # compute eigenvalues
            if t % 10 == 0:
                W = self.W1.mm(self.W2)
                # W = self.W1
                s = np.linalg.svd(W.cpu().numpy(), compute_uv=0)
                s = torch.unsqueeze(torch.from_numpy(s).type(dtype), 1).t()
                self.strenghts = torch.cat((self.strenghts, s), dim=0)

                testing_activations = self.encode(Y.type(dtype))
                z_testing_activations = self.encode(UZ.type(dtype)) if UZ is not None else 0.0
                
                self.history['weights']['W1'].append(W1.cpu().numpy().copy())
                self.history['weights']['W2'].append(W2.cpu().numpy().copy())
                self.history['activations'].append(h1.cpu().numpy().copy())
                self.history['testing_activations'].append(testing_activations.cpu().numpy().copy())
                self.history['z_testing_activations'].append(z_testing_activations.cpu().numpy().copy())
        
    def predict(self, X):
        W1 = self.W1
        W2 = self.W2
        h1 = X.type(torch.cuda.FloatTensor).mm(W1)
        scores = h1.mm(W2)
        return scores
    
    def encode(self, X):
        W1 = self.W1
        W2 = self.W2
        h1 = X.type(torch.cuda.FloatTensor).mm(W1)
        # scores = h1.mm(W2)
        return h1

# %% [markdown]
# ### Case 1

# %% [markdown]
# #### Data

# %%
# training means and shared std
means_train = [
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
    # np.array([0.0, -10.0, -10.0, 0.0]),  # /ø/
    # np.array([0.0, -10.0, 10.0, 0.0]),  # /o/
]
var_strength = 5.0  # Hz in all dimensions
vars_train = [var_strength] * len(means_train)
sizes_train = [100 // len(means_train)] * len(means_train)  # for example
tags_train = ["y", "u"] # , "ø", "o"

means_test = [
    np.array([0.0, 5.0, -10.0, 0.0]),  # /ø/
    np.array([0.0, 5.0, 10.0, 0.0]),  # /o/
    np.array([0.0, 10.0, -10.0, 5.0]),  # /ɛ/
    np.array([0.0, 10.0, 10.0, 5.0]),  # /ʌ/
    np.array([0.0, 0.0, -10.0, 5.0]),  # /i/
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
]
vars_test = [var_strength] * len(means_test)
sizes_test = [50] * len(means_test)  # for example
tags_test = ["ø", "o", "ɛ", "ʌ", "i", "y", "u"]

data_train, labels_train = generate_gmm_data(d=4, n_components=len(tags_train), random_state=calendar.timegm(time.gmtime()), means=means_train, vars=vars_train, sizes=sizes_train, tags=tags_train)

data_test, labels_test = generate_gmm_data(d=4, n_components=len(tags_test), random_state=calendar.timegm(time.gmtime()) + 1, means=means_test, vars=vars_test, sizes=sizes_test, tags=tags_test)

# %% [markdown]
# #### Debuggings

# %%
corr_mat = compute_correlation_matrix(data_train, data_train)
U, S, V = np.linalg.svd(corr_mat)

# %%
S
# Out:
# array([2.40118305e+02, 1.11211193e+01, 2.01322846e-15, 6.30213608e-17])

# %%
C = np.cov(data_train, rowvar=False)
U_, S_, Vt_ = np.linalg.svd(C)

# %%
U @ np.array([1, 0, 0, 0])
# Out:
# array([-0.00344738, -0.28221781, -0.9588045 ,  0.03217367])

# %%
U
# Out:
# array([[ 0.02222058, -0.31260571,  0.3887682 , -0.86639668],
#        [ 0.03650479,  0.06516327, -0.90118373, -0.42695319],
#        [-0.99887259, -0.02417506, -0.02820856, -0.02955327],
#        [-0.02066878,  0.94733679,  0.18955592, -0.25728266]])

# %%
U @ np.array([1, 0, 0, 0]), U @ np.array([-1, 0, 0, 0])
# Out:
# (array([ 0.02222058,  0.03650479, -0.99887259, -0.02066878]),
#  array([-0.02222058, -0.03650479,  0.99887259,  0.02066878]))

# %%
plt.figure()
plt.imshow(abs(U), aspect='equal')
plt.colorbar()
plt.title("Covariance Matrix")
plt.xlabel("Dimension")
plt.ylabel("Dimension")
plt.show()

# %%
plot_2d_projection_with_principal_axes(data_train, labels_train, dim_x=2, dim_y=3)

# %% [markdown]
# #### Pre-training Test

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 5000
lr = 0.0005
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):

# create dynamics plot
slices = (0, 1, 2, 3)
fig, ax1 = plt.subplots(1, 1, figsize=(12, 8), sharey='row', sharex='col')
# axes = [ax1, ax2]

w0 = 1e-7
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
         label='Theory ($\gamma = 0$)')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
# ax2.yaxis.set_label_position('right')
# ax2.set_ylabel('MNIST')
plt.show()

# %% [markdown]
# #### Training

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 10000
lr = 0.001
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()
z_data = torch.from_numpy(np.array(
    [
        [10.0, 0.0, 0.0, 0.0],
        [-10.0, 0.0, 0.0, 0.0],
        [0.0, 10.0, 0.0, 0.0],
        [0.0, -10.0, 0.0, 0.0],
        [0.0, 0.0, 10.0, 0.0],
        [0.0, 0.0, -10.0, 0.0],
        [0.0, 0.0, 0.0, 10.0],
        [0.0, 0.0, 0.0, -10.0]
    ]
)).float()  # for testing
z_labels = np.array(
    [
        '1+', '1-',
        '2+', '2-',
        '3+', '3-',
        '4+', '4-'
    ]
)

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):
t = 1
laeModel = LinearAutoEncoder()
laeModel.train(input_data, None, input_dim=4, 
                n_epoch=epochs, hidden_dim=hidden_dim, 
                learning_rate=lr, reg_param=reg[t], 
                noise='Gaussian', noise_scale=var[t], verbose=True, 
                Y=torch.from_numpy(data_test).float(), 
                Y_val=labels_test, 
                Z=z_data,
                Z_val=z_labels)
recorded_models.append(laeModel)
# Out:
# iteration:  0 training loss:  tensor(56.5622, device='cuda:0')
# iteration:  100 training loss:  tensor(19.6570, device='cuda:0')
# iteration:  200 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  300 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  400 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  500 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  600 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  700 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  800 training loss:  tensor(6.3501, device='cuda:0')
# iteration:  900 training loss:  tensor(6.3500, device='cuda:0')
# iteration:  1000 training loss:  tensor(6.3499, device='cuda:0')
# iteration:  1100 training loss:  tensor(6.3497, device='cuda:0')
# iteration:  1200 training loss:  tensor(6.3491, device='cuda:0')
# iteration:  1300 training loss:  tensor(6.3477, device='cuda:0')
# iteration:  1400 training loss:  tensor(6.3446, device='cuda:0')
# iteration:  1500 training loss:  tensor(6.3374, device='cuda:0')
# iteration:  1600 training loss:  tensor(6.3207, device='cuda:0')
# iteration:  1700 training loss:  tensor(6.2826, device='cuda:0')
# iteration:  1800 training loss:  tensor(6.1980, device='cuda:0')
# iteration:  1900 training loss:  tensor(6.0216, device='cuda:0')
# iteration:  2000 training loss:  tensor(5.7000, device='cuda:0')
# iteration:  2100 training loss:  tensor(5.2449, device='cuda:0')
# iteration:  2200 training loss:  tensor(4.8135, device='cuda:0')
# iteration:  7000 training loss:  tensor(4.4254, device='cuda:0')
# iteration:  7100 training loss:  tensor(4.4252, device='cuda:0')
# iteration:  7200 training loss:  tensor(4.4250, device='cuda:0')
# iteration:  7300 training loss:  tensor(4.4248, device='cuda:0')
# iteration:  7400 training loss:  tensor(4.4246, device='cuda:0')
# iteration:  7500 training loss:  tensor(4.4244, device='cuda:0')
# iteration:  7600 training loss:  tensor(4.4242, device='cuda:0')
# iteration:  7700 training loss:  tensor(4.4241, device='cuda:0')
# iteration:  7800 training loss:  tensor(4.4239, device='cuda:0')
# iteration:  7900 training loss:  tensor(4.4237, device='cuda:0')
# iteration:  8000 training loss:  tensor(4.4235, device='cuda:0')
# iteration:  8100 training loss:  tensor(4.4234, device='cuda:0')
# iteration:  8200 training loss:  tensor(4.4232, device='cuda:0')
# iteration:  8300 training loss:  tensor(4.4231, device='cuda:0')
# iteration:  8400 training loss:  tensor(4.4229, device='cuda:0')
# iteration:  8500 training loss:  tensor(4.4228, device='cuda:0')
# iteration:  8600 training loss:  tensor(4.4226, device='cuda:0')
# iteration:  8700 training loss:  tensor(4.4225, device='cuda:0')
# iteration:  8800 training loss:  tensor(4.4224, device='cuda:0')
# iteration:  8900 training loss:  tensor(4.4222, device='cuda:0')
# iteration:  9000 training loss:  tensor(4.4221, device='cuda:0')
# iteration:  9100 training loss:  tensor(4.4220, device='cuda:0')
# iteration:  9200 training loss:  tensor(4.4219, device='cuda:0')
# iteration:  9300 training loss:  tensor(4.4218, device='cuda:0')
# iteration:  9400 training loss:  tensor(4.4216, device='cuda:0')
# iteration:  9500 training loss:  tensor(4.4215, device='cuda:0')
# iteration:  9600 training loss:  tensor(4.4214, device='cuda:0')
# iteration:  9700 training loss:  tensor(4.4213, device='cuda:0')
# iteration:  9800 training loss:  tensor(4.4212, device='cuda:0')
# iteration:  9900 training loss:  tensor(4.4211, device='cuda:0')

# %%
def average_inner_product(X1, X2):
    # X1, X2: arrays of shape (N1, D), (N2, D)
    # Compute inner products for all pairs, return the mean
    ip = np.dot(X1, X2.T)  # shape (N1, N2)
    return ip.mean()

def average_cosine_similarity(A, B):
    """
    Computes cosine similarity between all pairs of rows in A (N1, D) and B (N2, D)
    Returns an (N1, N2) matrix of similarities.
    """
    # Normalize each row to unit length
    A_norm = A / np.linalg.norm(A, axis=1, keepdims=True)
    B_norm = B / np.linalg.norm(B, axis=1, keepdims=True)
    # Compute cosine similarity as dot product
    sim_matrix = np.dot(A_norm, B_norm.T)
    return sim_matrix.mean()  # shape (N1, N2)

def average_euclidean_distance(A, B):
    """
    Returns the matrix of Euclidean distances between all pairs in A (N1, D) and B (N2, D)
    Output: (N1, N2)
    """
    # Efficient computation: (a - b)^2 = a^2 + b^2 - 2ab
    A_sq = np.sum(A**2, axis=1, keepdims=True)  # (N1, 1)
    B_sq = np.sum(B**2, axis=1, keepdims=True).T  # (1, N2)
    cross = np.dot(A, B.T)  # (N1, N2)
    dist_sq = A_sq + B_sq - 2 * cross
    dist_sq = np.maximum(dist_sq, 0.0)  # for numerical safety
    distances = np.sqrt(dist_sq)
    return distances.mean()  # shape (N1, N2)

def similarity_trajectory(recon_test, labels_test, label_a, label_b, calculator=average_inner_product):
    sims = []
    for epoch_data in recon_test:  # each is (N_test, D)
        idx_a = np.where(labels_test == label_a)[0]
        idx_b = np.where(labels_test == label_b)[0]
        X_a = epoch_data[idx_a]
        X_b = epoch_data[idx_b]
        sim = calculator(X_a, X_b)
        sims.append(sim)
    return sims

# %% [markdown]
# #### Principle Direction Contrast

# %%
similarity_curves = {}
for contrast_pair in [("1+", "1-"), ("2+", "2-"), ("3+", "3-"), ("4+", "4-")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["z_testing_activations"], z_labels, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Mock Vowel Contrast

# %%
similarity_curves = {}
for contrast_pair in [("ø", "o"), ("ɛ", "ʌ"), ("i", "ɛ"), ("y", "u"), ("u", "o")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["testing_activations"], labels_test, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
similarity_curves.keys()
# Out:
# dict_keys([('ø', 'o'), ('ɛ', 'ʌ'), ('i', 'ɛ'), ('y', 'u'), ('u', 'o')])

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[('y', 'u')] - similarity_curves[('i', 'ɛ')])[:])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Theoretical vs Simulation

# %%
# create dynamics plot
slices = (0, 1, 2, 3)
fig, [(ax1, ax2), (ax3, ax4)] = plt.subplots(2, 2, figsize=(12, 8), sharey='row', sharex='col')
axes = [ax1, ax2]

# get actual dynamics
actual_dynamics_mnist = recorded_models[0].strenghts.cpu().numpy()
# actual_dynamics_reg_mnist = recorded_models[1].strenghts.cpu().numpy()
# actual_dynamics_mnist = recorded_models[0].history['weights']['W1']
# actual_dynamics_reg_mnist = recorded_models[1].history['weights']['W1']
# actual_dynamics_noise_mnist = mnist_models[2].strenghts.cpu().numpy()
w0 = recorded_models[0].init
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
         label='Theory ($\gamma = 0$)')

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
for s in slices:
    ax1.scatter(x_p[rangestart:], actual_dynamics_mnist[rangestart:, s], c='blue', 
                marker='x', label='Actual ($\gamma = 0$)')
    # ax1.scatter(x_p[rangestart:], actual_dynamics_reg_mnist[rangestart:, s], c='orange', 
    #             marker='x', label='Actual ($\gamma = $' + str(reg_param) + ')')
    # ax2.scatter(x_p, actual_dynamics_mnist[:, s], c='blue', 
    #             marker='x', label='Actual ($\sigma^2 = 0$)')
    # ax2.scatter(x_p, actual_dynamics_noise_mnist[:, s], c='darkgreen',
    #             marker='x', label='Actual ($\sigma^2 = $' + str(var_param) + ')')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
ax2.yaxis.set_label_position('right')
ax2.set_ylabel('MNIST')
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\g'
# <>:28: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\g'
# <>:28: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_971751/1844846676.py:18: SyntaxWarning: invalid escape sequence '\g'
#   marker='x', label='Actual ($\gamma = 0$)')
# /tmp/ipykernel_971751/1844846676.py:28: SyntaxWarning: invalid escape sequence '\c'
#   ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)

# %%
import numpy as np


# Helper functions to compute theoretical learning dynamics
def dae_learning_dynamics(lam, var, gamma, N, n_epoch, learning_rate, u0):
    dynamics = []
    tau = N/learning_rate
    g = N*gamma
    xi = lam + N*var
    
    for t in range(n_epoch):
        E = np.exp((2*(lam - g)*t)/tau)
        num = (lam - g)*E
        denom = xi*(E - 1) + (lam - g)/u0
        uf = num/denom
        dynamics.append(uf)
    
    return np.asarray(dynamics)
  
def compute_correlation_matrix(x, y):
    mat = np.zeros((y.shape[1], x.shape[1]))
    for x_vec, y_vec in zip(x, y):
        mat += np.outer(y_vec, x_vec)
    return mat
  
def theoretical_learning_dynamics(X, y, n_epoch, lr, var, reg, u0 = 2.5e-7):
    dyns = np.zeros((1,X.shape[1]))
    corr_mat = compute_correlation_matrix(X, y)
    U, S, V = np.linalg.svd(corr_mat)
    dyns = dae_learning_dynamics(S, var, reg, X.shape[0], n_epoch, lr, u0)
    return dyns

# %% [markdown]
# ### Case 2

# %% [markdown]
# #### Data

# %%
# training means and shared std
means_train = [
    np.array([0.0, 0.0, 0.0, -2.5]),  # /y/
    np.array([0.0, 0.0, 0.0, 2.5]),  # /i/
]
var_strength = 1.0  # Hz in all dimensions
vars_train = [var_strength] * len(means_train)
sizes_train = [100 // len(means_train)] * len(means_train)  # for example
tags_train = ["y", "i"] # , "ø", "o"

means_test = [
    np.array([0.0, 5.0, -10.0, 0.0]),  # /ø/
    np.array([0.0, 5.0, 10.0, 0.0]),  # /o/
    np.array([0.0, 10.0, -10.0, 5.0]),  # /ɛ/
    np.array([0.0, 10.0, 10.0, 5.0]),  # /ʌ/
    np.array([0.0, 0.0, -10.0, 5.0]),  # /i/
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
]
vars_test = [var_strength] * len(means_test)
sizes_test = [50] * len(means_test)  # for example
tags_test = ["ø", "o", "ɛ", "ʌ", "i", "y", "u"]

data_train, labels_train = generate_gmm_data(d=4, n_components=len(tags_train), random_state=calendar.timegm(time.gmtime()), means=means_train, vars=vars_train, sizes=sizes_train, tags=tags_train)

data_test, labels_test = generate_gmm_data(d=4, n_components=len(tags_test), random_state=calendar.timegm(time.gmtime()) + 1, means=means_test, vars=vars_test, sizes=sizes_test, tags=tags_test)

# %% [markdown]
# #### Debuggings

# %%
corr_mat = compute_correlation_matrix(data_train, data_train)
U, S, V = np.linalg.svd(corr_mat)

# %%
S
# Out:
# array([807.32838728, 114.41516351, 103.00572227, 100.37299002])

# %%
C = np.cov(data_train, rowvar=False)
U_, S_, Vt_ = np.linalg.svd(C)

# %%
U @ np.array([1, 0, 0, 0])
# Out:
# array([-0.04692535, -0.05827265, -0.01110716, -0.99713537])

# %%
U
# Out:
# array([[-0.04692535,  0.75029187, -0.56279914, -0.3436819 ],
#        [-0.05827265,  0.62587662,  0.45332152,  0.63196705],
#        [-0.01110716,  0.19962081,  0.69115653, -0.6945004 ],
#        [-0.99713537, -0.07410871, -0.00770556, -0.01302238]])

# %%
U @ np.array([1, 0, 0, 0]), U @ np.array([-1, 0, 0, 0])
# Out:
# (array([-0.04692535, -0.05827265, -0.01110716, -0.99713537]),
#  array([0.04692535, 0.05827265, 0.01110716, 0.99713537]))

# %%
plt.figure()
plt.imshow(abs(U), aspect='equal')
plt.colorbar()
plt.title("Covariance Matrix")
plt.xlabel("Dimension")
plt.ylabel("Dimension")
plt.show()

# %%
plot_2d_projection_with_principal_axes(data_train, labels_train, dim_x=2, dim_y=3)

# %% [markdown]
# #### Pre-training Test

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 5000
lr = 0.0005
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):

# create dynamics plot
slices = (0, 1, 2, 3)
fig, ax1 = plt.subplots(1, 1, figsize=(12, 8), sharey='row', sharex='col')
# axes = [ax1, ax2]

w0 = 1e-7
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
         label='Theory ($\gamma = 0$)')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
# ax2.yaxis.set_label_position('right')
# ax2.set_ylabel('MNIST')
plt.show()

# %% [markdown]
# #### Training

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 50000
lr = 0.001
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()
z_data = torch.from_numpy(np.array(
    [
        [10.0, 0.0, 0.0, 0.0],
        [-10.0, 0.0, 0.0, 0.0],
        [0.0, 10.0, 0.0, 0.0],
        [0.0, -10.0, 0.0, 0.0],
        [0.0, 0.0, 10.0, 0.0],
        [0.0, 0.0, -10.0, 0.0],
        [0.0, 0.0, 0.0, 10.0],
        [0.0, 0.0, 0.0, -10.0]
    ]
)).float()  # for testing
z_labels = np.array(
    [
        '1+', '1-',
        '2+', '2-',
        '3+', '3-',
        '4+', '4-'
    ]
)

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):
t = 1
laeModel = LinearAutoEncoder()
laeModel.train(input_data, None, input_dim=4, 
                n_epoch=epochs, hidden_dim=hidden_dim, 
                learning_rate=lr, reg_param=reg[t], 
                noise='Gaussian', noise_scale=var[t], verbose=True, 
                Y=torch.from_numpy(data_test).float(), 
                Y_val=labels_test, 
                Z=z_data,
                Z_val=z_labels)
recorded_models.append(laeModel)
# Out:
# iteration:  0 training loss:  tensor(5.6256, device='cuda:0')
# iteration:  100 training loss:  tensor(5.6256, device='cuda:0')
# iteration:  200 training loss:  tensor(5.6256, device='cuda:0')
# iteration:  300 training loss:  tensor(5.6256, device='cuda:0')
# iteration:  400 training loss:  tensor(5.6255, device='cuda:0')
# iteration:  500 training loss:  tensor(5.6253, device='cuda:0')
# iteration:  600 training loss:  tensor(5.6243, device='cuda:0')
# iteration:  700 training loss:  tensor(5.6198, device='cuda:0')
# iteration:  800 training loss:  tensor(5.5994, device='cuda:0')
# iteration:  900 training loss:  tensor(5.5092, device='cuda:0')
# iteration:  1000 training loss:  tensor(5.1413, device='cuda:0')
# iteration:  1100 training loss:  tensor(4.0378, device='cuda:0')
# iteration:  1200 training loss:  tensor(2.6111, device='cuda:0')
# iteration:  1300 training loss:  tensor(2.1264, device='cuda:0')
# iteration:  1400 training loss:  tensor(2.0765, device='cuda:0')
# iteration:  1500 training loss:  tensor(2.0736, device='cuda:0')
# iteration:  1600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  1700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  1800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  1900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  2900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  3900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  4900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  5900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  6900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  7900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8400 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8500 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8600 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8700 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8800 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  8900 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  9000 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  9100 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  9200 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  9300 training loss:  tensor(2.0735, device='cuda:0')
# iteration:  9400 training loss:  tensor(2.0734, device='cuda:0')
# iteration:
training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39300 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39400 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39500 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39600 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39700 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39800 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  39900 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  40000 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  40100 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  40200 training loss:  tensor(1.8927, device='cuda:0')
# iteration:  40300 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40400 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40500 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40600 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40700 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40800 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  40900 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41000 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41100 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41200 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41300 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41400 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41500 training loss:  tensor(1.8926, device='cuda:0')
# iteration:  41600 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  41700 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  41800 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  41900 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42000 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42100 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42200 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42300 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42400 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42500 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42600 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42700 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42800 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  42900 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  43000 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  43100 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  43200 training loss:  tensor(1.8925, device='cuda:0')
# iteration:  43300 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43400 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43500 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43600 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43700 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43800 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  43900 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44000 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44100 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44200 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44300 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44400 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44500 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44600 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44700 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44800 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  44900 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45000 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45100 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45200 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45300 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45400 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45500 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45600 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45700 training loss:  tensor(1.8924, device='cuda:0')
# iteration:  45800 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  45900 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46000 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46100 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46200 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46300 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46400 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46500 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46600 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46700 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46800 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  46900 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47000 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47100 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47200 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47300 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47400 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47500 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47600 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47700 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47800 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  47900 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48000 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48100 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48200 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48300 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48400 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48500 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48600 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48700 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48800 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  48900 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49000 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49100 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49200 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49300 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49400 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49500 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49600 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49700 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49800 training loss:  tensor(1.8923, device='cuda:0')
# iteration:  49900 training loss:  tensor(1.8923, device='cuda:0')

# %%
def average_inner_product(X1, X2):
    # X1, X2: arrays of shape (N1, D), (N2, D)
    # Compute inner products for all pairs, return the mean
    ip = np.dot(X1, X2.T)  # shape (N1, N2)
    return ip.mean()

def average_cosine_similarity(A, B):
    """
    Computes cosine similarity between all pairs of rows in A (N1, D) and B (N2, D)
    Returns an (N1, N2) matrix of similarities.
    """
    # Normalize each row to unit length
    A_norm = A / np.linalg.norm(A, axis=1, keepdims=True)
    B_norm = B / np.linalg.norm(B, axis=1, keepdims=True)
    # Compute cosine similarity as dot product
    sim_matrix = np.dot(A_norm, B_norm.T)
    return sim_matrix.mean()  # shape (N1, N2)

def average_euclidean_distance(A, B):
    """
    Returns the matrix of Euclidean distances between all pairs in A (N1, D) and B (N2, D)
    Output: (N1, N2)
    """
    # Efficient computation: (a - b)^2 = a^2 + b^2 - 2ab
    A_sq = np.sum(A**2, axis=1, keepdims=True)  # (N1, 1)
    B_sq = np.sum(B**2, axis=1, keepdims=True).T  # (1, N2)
    cross = np.dot(A, B.T)  # (N1, N2)
    dist_sq = A_sq + B_sq - 2 * cross
    dist_sq = np.maximum(dist_sq, 0.0)  # for numerical safety
    distances = np.sqrt(dist_sq)
    return distances.mean()  # shape (N1, N2)

def similarity_trajectory(recon_test, labels_test, label_a, label_b, calculator=average_inner_product):
    sims = []
    for epoch_data in recon_test:  # each is (N_test, D)
        idx_a = np.where(labels_test == label_a)[0]
        idx_b = np.where(labels_test == label_b)[0]
        X_a = epoch_data[idx_a]
        X_b = epoch_data[idx_b]
        sim = calculator(X_a, X_b)
        sims.append(sim)
    return sims

# %% [markdown]
# #### Principle Direction Contrast

# %%
recorded_models[0].history["weights"]["W1"][1000]
# Out:
# array([[-0.04234373, -0.01753673],
#        [-0.05114589, -0.02427647],
#        [-0.00488022, -0.01309286],
#        [-0.8369725 , -0.48185006]], dtype=float32)

# %% [markdown]
# - Interim conclusion: if we only have this one contrast, it is still very safe, and it will be learned as well. However, if variance is too large or if this contrast is embedded in a larger language with multiple contrasts that are much more salient, it will be hard to learn.

# %%
similarity_curves = {}
for contrast_pair in [("1+", "1-"), ("2+", "2-"), ("3+", "3-"), ("4+", "4-")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["z_testing_activations"], z_labels, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Mock Vowel Contrast

# %%
similarity_curves = {}
for contrast_pair in [("ø", "o"), ("ɛ", "ʌ"), ("i", "ɛ"), ("y", "u"), ("u", "o")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["testing_activations"], labels_test, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
similarity_curves.keys()
# Out:
# dict_keys([('ø', 'o'), ('ɛ', 'ʌ'), ('i', 'ɛ'), ('y', 'u'), ('u', 'o')])

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[('y', 'u')] - similarity_curves[('i', 'ɛ')])[:])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Theoretical vs Simulation

# %%
# create dynamics plot
slices = (0, 1, 2, 3)
fig, [(ax1, ax2), (ax3, ax4)] = plt.subplots(2, 2, figsize=(12, 8), sharey='row', sharex='col')
axes = [ax1, ax2]

# get actual dynamics
actual_dynamics_mnist = recorded_models[0].strenghts.cpu().numpy()
# actual_dynamics_reg_mnist = recorded_models[1].strenghts.cpu().numpy()
# actual_dynamics_mnist = recorded_models[0].history['weights']['W1']
# actual_dynamics_reg_mnist = recorded_models[1].history['weights']['W1']
# actual_dynamics_noise_mnist = mnist_models[2].strenghts.cpu().numpy()
w0 = recorded_models[0].init
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# # plot simulated dynamics
# x_p = np.arange(0, epochs+1, 1)
# rangestart = 0
# ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
#          label='Theory ($\gamma = 0$)')

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 10)
rangestart = 0
for s in slices:
    ax1.scatter(x_p[rangestart:], actual_dynamics_mnist[rangestart:, s], c='blue', 
                marker='x', label='Actual ($\gamma = 0$)')
    # ax1.scatter(x_p[rangestart:], actual_dynamics_reg_mnist[rangestart:, s], c='orange', 
    #             marker='x', label='Actual ($\gamma = $' + str(reg_param) + ')')
    # ax2.scatter(x_p, actual_dynamics_mnist[:, s], c='blue', 
    #             marker='x', label='Actual ($\sigma^2 = 0$)')
    # ax2.scatter(x_p, actual_dynamics_noise_mnist[:, s], c='darkgreen',
    #             marker='x', label='Actual ($\sigma^2 = $' + str(var_param) + ')')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
ax2.yaxis.set_label_position('right')
ax2.set_ylabel('MNIST')
plt.show()

# %%
import numpy as np


# Helper functions to compute theoretical learning dynamics
def dae_learning_dynamics(lam, var, gamma, N, n_epoch, learning_rate, u0):
    dynamics = []
    tau = N/learning_rate
    g = N*gamma
    xi = lam + N*var
    
    for t in range(n_epoch):
        E = np.exp((2*(lam - g)*t)/tau)
        num = (lam - g)*E
        denom = xi*(E - 1) + (lam - g)/u0
        uf = num/denom
        dynamics.append(uf)
    
    return np.asarray(dynamics)
  
def compute_correlation_matrix(x, y):
    mat = np.zeros((y.shape[1], x.shape[1]))
    for x_vec, y_vec in zip(x, y):
        mat += np.outer(y_vec, x_vec)
    return mat
  
def theoretical_learning_dynamics(X, y, n_epoch, lr, var, reg, u0 = 2.5e-7):
    dyns = np.zeros((1,X.shape[1]))
    corr_mat = compute_correlation_matrix(X, y)
    U, S, V = np.linalg.svd(corr_mat)
    dyns = dae_learning_dynamics(S, var, reg, X.shape[0], n_epoch, lr, u0)
    return dyns

# %% [markdown]
# ### Case 3: Multiple contrast one large one small

# %% [markdown]
# #### Data

# %%
# training means and shared std
means_train = [
    np.array([0.0, 0.0, -10.0, -2.5]),  # /y/
    np.array([0.0, 0.0, -10.0, 2.5]),  # /i/
    np.array([0.0, 0.0, 10.0, -2.5]),  # /u/
    np.array([0.0, 0.0, 10.0, 2.5]),  # /uu/
]
var_strength = 5.0  # Hz in all dimensions
vars_train = [var_strength] * len(means_train)
sizes_train = [100 // len(means_train)] * len(means_train)  # for example
tags_train = ["y", "i", "u", "uu"] # , "ø", "o"

means_test = [
    np.array([0.0, 5.0, -10.0, -2.5]),  # /ø/
    np.array([0.0, 5.0, -10.0, 2.5]),  # /e/
    np.array([0.0, 5.0, 10.0, -2.5]),  # /o/
    np.array([0.0, 10.0, -10.0, 2.5]),  # /ɛ/
    np.array([0.0, 10.0, 10.0, 2.5]),  # /ʌ/
    np.array([0.0, 10.0, 10.0, -2.5]),  # /c/
    np.array([0.0, 0.0, -10.0, 2.5]),  # /i/
    np.array([0.0, 0.0, -10.0, -2.5]),  # /y/
    np.array([0.0, 0.0, 10.0, -2.5]),  # /u/
     np.array([0.0, 0.0, 10.0, 2.5]), # /uu/
]
vars_test = [var_strength] * len(means_test)
sizes_test = [50] * len(means_test)  # for example
tags_test = ["ø", "e", "o", "ɛ", "ʌ", "c", "i", "y", "u", "uu"]

data_train, labels_train = generate_gmm_data(d=4, n_components=len(tags_train), random_state=calendar.timegm(time.gmtime()), means=means_train, vars=vars_train, sizes=sizes_train, tags=tags_train)

data_test, labels_test = generate_gmm_data(d=4, n_components=len(tags_test), random_state=calendar.timegm(time.gmtime()) + 1, means=means_test, vars=vars_test, sizes=sizes_test, tags=tags_test)

# %% [markdown]
# #### Debuggings

# %%
corr_mat = compute_correlation_matrix(data_train, data_train)
U, S, V = np.linalg.svd(corr_mat)

# %%
S
# Out:
# array([9648.60519989, 1145.8536813 ,  571.26165087,  446.87115715])

# %%
C = np.cov(data_train, rowvar=False)
U_, S_, Vt_ = np.linalg.svd(C)

# %%
U @ np.array([1, 0, 0, 0])
# Out:
# array([-0.0394741 , -0.00496212,  0.99875795, -0.02999537])

# %%
U
# Out:
# array([[-0.0394741 ,  0.04676956, -0.92926813, -0.3643009 ],
#        [-0.00496212, -0.07510977,  0.36085363, -0.92957978],
#        [ 0.99875795, -0.02842738, -0.03703153, -0.01740975],
#        [-0.02999537, -0.99567214, -0.06981453,  0.05350882]])

# %%
U @ np.array([1, 0, 0, 0]), U @ np.array([-1, 0, 0, 0])
# Out:
# (array([-0.0394741 , -0.00496212,  0.99875795, -0.02999537]),
#  array([ 0.0394741 ,  0.00496212, -0.99875795,  0.02999537]))

# %%
plt.figure()
plt.imshow(abs(U), aspect='equal')
plt.colorbar()
plt.title("Covariance Matrix")
plt.xlabel("Dimension")
plt.ylabel("Dimension")
plt.show()

# %%
plot_2d_projection_with_principal_axes(data_train, labels_train, dim_x=2, dim_y=3)

# %% [markdown]
# #### Pre-training Test

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 5000
lr = 0.0005
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):

# create dynamics plot
slices = (0, 1, 2, 3)
fig, ax1 = plt.subplots(1, 1, figsize=(12, 8), sharey='row', sharex='col')
# axes = [ax1, ax2]

w0 = 1e-7
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
         label='Theory ($\gamma = 0$)')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
# ax2.yaxis.set_label_position('right')
# ax2.set_ylabel('MNIST')
plt.show()

# %% [markdown]
# #### Training

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 10000
lr = 0.001
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()
z_data = torch.from_numpy(np.array(
    [
        [10.0, 0.0, 0.0, 0.0],
        [-10.0, 0.0, 0.0, 0.0],
        [0.0, 10.0, 0.0, 0.0],
        [0.0, -10.0, 0.0, 0.0],
        [0.0, 0.0, 10.0, 0.0],
        [0.0, 0.0, -10.0, 0.0],
        [0.0, 0.0, 0.0, 10.0],
        [0.0, 0.0, 0.0, -10.0]
    ]
)).float()  # for testing
z_labels = np.array(
    [
        '1+', '1-',
        '2+', '2-',
        '3+', '3-',
        '4+', '4-'
    ]
)

# set seed
np.random.seed(123)
torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):
t = 1
laeModel = LinearAutoEncoder()
laeModel.train(input_data, None, input_dim=4, 
                n_epoch=epochs, hidden_dim=hidden_dim, 
                learning_rate=lr, reg_param=reg[t], 
                noise='Gaussian', noise_scale=var[t], verbose=True, 
                Y=torch.from_numpy(data_test).float(), 
                Y_val=labels_test, 
                Z=z_data,
                Z_val=z_labels)
recorded_models.append(laeModel)
# Out:
# iteration:  0 training loss:  tensor(59.0630, device='cuda:0')
# iteration:  100 training loss:  tensor(35.4148, device='cuda:0')
# iteration:  200 training loss:  tensor(11.3186, device='cuda:0')
# iteration:  300 training loss:  tensor(11.3185, device='cuda:0')
# iteration:  400 training loss:  tensor(11.3177, device='cuda:0')
# iteration:  500 training loss:  tensor(11.3100, device='cuda:0')
# iteration:  600 training loss:  tensor(11.2433, device='cuda:0')
# iteration:  700 training loss:  tensor(10.7047, device='cuda:0')
# iteration:  800 training loss:  tensor(8.1983, device='cuda:0')
# iteration:  900 training loss:  tensor(6.2159, device='cuda:0')
# iteration:  1000 training loss:  tensor(6.0807, device='cuda:0')
# iteration:  1100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  1900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  2900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  3900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  4900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  5900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  6900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  7900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  8900 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9000 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9100 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9200 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9300 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9400 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9500 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9600 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9700 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9800 training loss:  tensor(6.0785, device='cuda:0')
# iteration:  9900 training loss:  tensor(6.0785, device='cuda:0')

# %%
def average_inner_product(X1, X2):
    # X1, X2: arrays of shape (N1, D), (N2, D)
    # Compute inner products for all pairs, return the mean
    ip = np.dot(X1, X2.T)  # shape (N1, N2)
    return ip.mean()

def average_cosine_similarity(A, B):
    """
    Computes cosine similarity between all pairs of rows in A (N1, D) and B (N2, D)
    Returns an (N1, N2) matrix of similarities.
    """
    # Normalize each row to unit length
    A_norm = A / np.linalg.norm(A, axis=1, keepdims=True)
    B_norm = B / np.linalg.norm(B, axis=1, keepdims=True)
    # Compute cosine similarity as dot product
    sim_matrix = np.dot(A_norm, B_norm.T)
    return sim_matrix.mean()  # shape (N1, N2)

def average_euclidean_distance(A, B):
    """
    Returns the matrix of Euclidean distances between all pairs in A (N1, D) and B (N2, D)
    Output: (N1, N2)
    """
    # Efficient computation: (a - b)^2 = a^2 + b^2 - 2ab
    A_sq = np.sum(A**2, axis=1, keepdims=True)  # (N1, 1)
    B_sq = np.sum(B**2, axis=1, keepdims=True).T  # (1, N2)
    cross = np.dot(A, B.T)  # (N1, N2)
    dist_sq = A_sq + B_sq - 2 * cross
    dist_sq = np.maximum(dist_sq, 0.0)  # for numerical safety
    distances = np.sqrt(dist_sq)
    return distances.mean()  # shape (N1, N2)

def similarity_trajectory(recon_test, labels_test, label_a, label_b, calculator=average_inner_product):
    sims = []
    for epoch_data in recon_test:  # each is (N_test, D)
        idx_a = np.where(labels_test == label_a)[0]
        idx_b = np.where(labels_test == label_b)[0]
        X_a = epoch_data[idx_a]
        X_b = epoch_data[idx_b]
        sim = calculator(X_a, X_b)
        sims.append(sim)
    return sims

def similarity_trajectory_normalized(recon_test, ori_test, labels_test, label_a, label_b, calculator=average_inner_product):
    sims = []
    for epoch_data in recon_test:  # each is (N_test, D)
        idx_a = np.where(labels_test == label_a)[0]
        idx_b = np.where(labels_test == label_b)[0]
        X_a = epoch_data[idx_a]
        X_b = epoch_data[idx_b]
        sim = calculator(X_a, X_b)

        ori_sim = calculator(ori_test[idx_a], ori_test[idx_b])
        norm_sim = sim / ori_sim if ori_sim != 0 else 0
        sims.append(norm_sim)
    return sims

# %% [markdown]
# #### Principle Direction Contrast

# %% [markdown]
# - Interim conclusion: if we only have this one contrast, it is still very safe, and it will be learned as well. However, if variance is too large or if this contrast is embedded in a larger language with multiple contrasts that are much more salient, it will be hard to learn.

# %%
similarity_curves = {}
for contrast_pair in [("1+", "1-"), ("2+", "2-"), ("3+", "3-"), ("4+", "4-")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["z_testing_activations"], z_labels, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Mock Vowel Contrast

# %%
similarity_curves = {}
for contrast_pair in [("ø", "o"), ("ɛ", "ʌ"), ("i", "ɛ"), ("y", "u"), ("u", "o"), ("ø", "e"), ("ʌ", "c"), ("i", "y"), ("u", "uu"), ("i", "uu")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory_normalized(recorded_models[0].history["testing_activations"], data_test, labels_test, label_a=label_a, label_b=label_b, 
                                                calculator=average_euclidean_distance)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:], marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
similarity_curves.keys()
# Out:
# dict_keys([('ø', 'o'), ('ɛ', 'ʌ'), ('i', 'ɛ'), ('y', 'u'), ('u', 'o'), ('ø', 'e'), ('ʌ', 'c'), ('i', 'y'), ('u', 'uu'), ('i', 'uu')])

# %%
native_pair = ('u', 'uu')
foreign_pair = ('u', 'o')
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[native_pair] - similarity_curves[foreign_pair])[:200])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {native_pair} and {foreign_pair} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
native_pair = ('i', 'uu')
foreign_pair = ('u', 'o')
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[native_pair] - similarity_curves[foreign_pair])[:150])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {native_pair} and {foreign_pair} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
native_pair = ('i', 'uu')
foreign_pair = ('y', 'u')
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[native_pair] - similarity_curves[foreign_pair])[:150])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {native_pair} and {foreign_pair} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
native_pair = ('y', 'u')
foreign_pair = ('ɛ', 'ʌ')
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[native_pair] - similarity_curves[foreign_pair])[:])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {native_pair} and {foreign_pair} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interim Conclusions
# 1. The larger the contrast, the faster it is learned. And the better it is learned finally.
# 2. Under current learning mechanisms, contrasts following the same trajectory have no difference in distinguishing. However, contrasts vertical to the L1 contrasts would not be learned.
# 3. Thus, the larger the contrast, the shorter the universal period. The smaller the contrast, the longer.
# 4. What was not expected was that if hidden representation dimension number is smaller than input, those small dimensions that will not be learned FINALLY, will show small learning and then de-learning DURING the process. I am not sure how this can be explained theoretically, but the effect size seems small, yet we may find something from this. (This is not related to contrasts parallel to L1 contrast)
# 5. When the training size is large, and if all the data are drawn from the same underlying distribution, both repeated training and online learning would converge to the same learning outcome. This means that although we are using small training dataset and large repetitions, it would be okay because it is similar to online learning of the same number of training steps (if we ignore overfitting).

# %% [markdown]
# #### Theoretical vs Simulation

# %%
# create dynamics plot
slices = (0, 1, 2, 3)
fig, [(ax1, ax2), (ax3, ax4)] = plt.subplots(2, 2, figsize=(12, 8), sharey='row', sharex='col')
axes = [ax1, ax2]

# get actual dynamics
actual_dynamics_mnist = recorded_models[0].strenghts.cpu().numpy()
# actual_dynamics_reg_mnist = recorded_models[1].strenghts.cpu().numpy()
# actual_dynamics_mnist = recorded_models[0].history['weights']['W1']
# actual_dynamics_reg_mnist = recorded_models[1].history['weights']['W1']
# actual_dynamics_noise_mnist = mnist_models[2].strenghts.cpu().numpy()
w0 = recorded_models[0].init
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# # plot simulated dynamics
# x_p = np.arange(0, epochs+1, 1)
# rangestart = 0
# ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
#          label='Theory ($\gamma = 0$)')

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 10)
rangestart = 0
for s in slices:
    ax1.scatter(x_p[rangestart:], actual_dynamics_mnist[rangestart:, s], c='blue', 
                marker='x', label='Actual ($\gamma = 0$)')
    # ax1.scatter(x_p[rangestart:], actual_dynamics_reg_mnist[rangestart:, s], c='orange', 
    #             marker='x', label='Actual ($\gamma = $' + str(reg_param) + ')')
    # ax2.scatter(x_p, actual_dynamics_mnist[:, s], c='blue', 
    #             marker='x', label='Actual ($\sigma^2 = 0$)')
    # ax2.scatter(x_p, actual_dynamics_noise_mnist[:, s], c='darkgreen',
    #             marker='x', label='Actual ($\sigma^2 = $' + str(var_param) + ')')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
ax2.yaxis.set_label_position('right')
ax2.set_ylabel('MNIST')
plt.show()

# %%
import numpy as np


# Helper functions to compute theoretical learning dynamics
def dae_learning_dynamics(lam, var, gamma, N, n_epoch, learning_rate, u0):
    dynamics = []
    tau = N/learning_rate
    g = N*gamma
    xi = lam + N*var
    
    for t in range(n_epoch):
        E = np.exp((2*(lam - g)*t)/tau)
        num = (lam - g)*E
        denom = xi*(E - 1) + (lam - g)/u0
        uf = num/denom
        dynamics.append(uf)
    
    return np.asarray(dynamics)
  
def compute_correlation_matrix(x, y):
    mat = np.zeros((y.shape[1], x.shape[1]))
    for x_vec, y_vec in zip(x, y):
        mat += np.outer(y_vec, x_vec)
    return mat
  
def theoretical_learning_dynamics(X, y, n_epoch, lr, var, reg, u0 = 2.5e-7):
    dyns = np.zeros((1,X.shape[1]))
    corr_mat = compute_correlation_matrix(X, y)
    U, S, V = np.linalg.svd(corr_mat)
    dyns = dae_learning_dynamics(S, var, reg, X.shape[0], n_epoch, lr, u0)
    return dyns

# %% [markdown]
# ### Case 4: Small contrasts

# %%
# training means and shared std
means_train = [
    # np.array([120.0, 320.0, 1650.0, 2250.0]),  # /y/
    # np.array([120.0, 320.0,  800.0, 2250.0]),  # /u/
    np.array([0.0, 0.0, 0.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 0.0, 5.0]),  # /i/
]
var_strength = 5.0  # Hz in all dimensions
vars_train = [var_strength] * len(means_train)
sizes_train = [100 // len(means_train)] * len(means_train)  # for example
tags_train = ["y", "i"]

means_test = [
    np.array([0.0, 5.0, -10.0, 0.0]),  # /ø/
    np.array([0.0, 5.0, 10.0, 0.0]),  # /o/
    np.array([0.0, 10.0, -10.0, 5.0]),  # /ɛ/
    np.array([0.0, 10.0, 10.0, 5.0]),  # /ʌ/
    np.array([0.0, 0.0, -10.0, 5.0]),  # /i/
    np.array([0.0, 0.0, -10.0, 0.0]),  # /y/
    np.array([0.0, 0.0, 10.0, 0.0]),  # /u/
]
vars_test = [var_strength] * len(means_test)
sizes_test = [50] * len(means_test)  # for example
tags_test = ["ø", "o", "ɛ", "ʌ", "i", "y", "u"]

data_train, labels_train = generate_gmm_data(d=4, n_components=len(tags_train), random_state=calendar.timegm(time.gmtime()), means=means_train, vars=vars_train, sizes=sizes_train, tags=tags_train)

data_test, labels_test = generate_gmm_data(d=4, n_components=len(tags_test), random_state=calendar.timegm(time.gmtime()) + 1, means=means_test, vars=vars_test, sizes=sizes_test, tags=tags_test)

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 5000
lr = 0.001
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

recorded_models = []

# convert to pytorch tensors
input_data = torch.from_numpy(data_train).float()

# set seed
# np.random.seed(123)
# torch.manual_seed(321)

# train autoencoder networks
# for t in range(num_trials):
t = 1
laeModel = LinearAutoEncoder()
laeModel.train(input_data, None, input_dim=4, 
                n_epoch=epochs, hidden_dim=hidden_dim, 
                learning_rate=lr, reg_param=reg[t], 
                noise='Gaussian', noise_scale=var[t], verbose=True, 
                Y=torch.from_numpy(data_test).float(), 
                Y_val=labels_test)
recorded_models.append(laeModel)
# Out:
# iteration:  0 training loss:  tensor(15.6311, device='cuda:0')
# iteration:  100 training loss:  tensor(15.6311, device='cuda:0')
# iteration:  200 training loss:  tensor(15.6311, device='cuda:0')
# iteration:  300 training loss:  tensor(15.6308, device='cuda:0')
# iteration:  400 training loss:  tensor(15.6228, device='cuda:0')
# iteration:  500 training loss:  tensor(15.4473, device='cuda:0')
# iteration:  600 training loss:  tensor(12.6771, device='cuda:0')
# iteration:  700 training loss:  tensor(8.1602, device='cuda:0')
# iteration:  800 training loss:  tensor(8.0268, device='cuda:0')
# iteration:  900 training loss:  tensor(8.0264, device='cuda:0')
# iteration:  1000 training loss:  tensor(8.0262, device='cuda:0')
# iteration:  1100 training loss:  tensor(8.0254, device='cuda:0')
# iteration:  1200 training loss:  tensor(8.0230, device='cuda:0')
# iteration:  1300 training loss:  tensor(8.0151, device='cuda:0')
# iteration:  1400 training loss:  tensor(7.9898, device='cuda:0')
# iteration:  1500 training loss:  tensor(7.9097, device='cuda:0')
# iteration:  1600 training loss:  tensor(7.6722, device='cuda:0')
# iteration:  1700 training loss:  tensor(7.0873, device='cuda:0')
# iteration:  1800 training loss:  tensor(6.1707, device='cuda:0')
# iteration:  1900 training loss:  tensor(5.5167, device='cuda:0')
# iteration:  2000 training loss:  tensor(5.3268, device='cuda:0')
# iteration:  2100 training loss:  tensor(5.2980, device='cuda:0')
# iteration:  2200 training loss:  tensor(5.2947, device='cuda:0')
# iteration:  2300 training loss:  tensor(5.2941, device='cuda:0')
# iteration:  2400 training loss:  tensor(5.2939, device='cuda:0')
# iteration:  2500 training loss:  tensor(5.2938, device='cuda:0')
# iteration:  2600 training loss:  tensor(5.2937, device='cuda:0')
# iteration:  2700 training loss:  tensor(5.2936, device='cuda:0')
# iteration:  2800 training loss:  tensor(5.2935, device='cuda:0')
# iteration:  2900 training loss:  tensor(5.2934, device='cuda:0')
# iteration:  3000 training loss:  tensor(5.2934, device='cuda:0')
# iteration:  3100 training loss:  tensor(5.2933, device='cuda:0')
# iteration:  3200 training loss:  tensor(5.2933, device='cuda:0')
# iteration:  3300 training loss:  tensor(5.2933, device='cuda:0')
# iteration:  3400 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  3500 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  3600 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  3700 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  3800 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  3900 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  4000 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  4100 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  4200 training loss:  tensor(5.2932, device='cuda:0')
# iteration:  4300 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4400 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4500 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4600 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4700 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4800 training loss:  tensor(5.2931, device='cuda:0')
# iteration:  4900 training loss:  tensor(5.2931, device='cuda:0')

# %%
similarity_curves = {}
for contrast_pair in [("ø", "o"), ("ɛ", "ʌ"), ("i", "ɛ"), ("y", "u"), ("u", "o"), ("y", "i")]:
    label_a, label_b = contrast_pair
    similarity_curve = similarity_trajectory(recorded_models[0].history["testing_activations"], labels_test, label_a=label_a, label_b=label_b, 
                                              calculator=average_cosine_similarity)
    similarity_curve = np.array(similarity_curve)
    similarity_curves[contrast_pair] = similarity_curve

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(similarity_curve[0:])
    plt.xlabel('Epoch')
    plt.ylabel('Average Inner Product Similarity')
    plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
similarity_curves.keys()
# Out:
# dict_keys([('ø', 'o'), ('ɛ', 'ʌ'), ('i', 'ɛ'), ('y', 'u'), ('u', 'o'), ('y', 'i')])

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.plot((similarity_curves[('y', 'i')] - similarity_curves[('i', 'ɛ')])[:])
plt.xlabel('Epoch')
plt.ylabel('Average Inner Product Similarity')
plt.title(f'Similarity Trajectory between {label_a} and {label_b} tokens')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# set parameters
num_samples = sum(sizes_train)
epochs = 5000
lr = 0.001
reg_param = 0.5
var_param = 0.5
reg = [0.0, reg_param, 0.0]
var = [0.0, 0.0, var_param]
num_trials = 2
hidden_dim = 2

# %%
# create dynamics plot
slices = (0, 1, 2, 3)
fig, [(ax1, ax2), (ax3, ax4)] = plt.subplots(2, 2, figsize=(12, 8), sharey='row', sharex='col')
axes = [ax1, ax2]

# get actual dynamics
actual_dynamics_mnist = recorded_models[0].strenghts.cpu().numpy()
# actual_dynamics_reg_mnist = recorded_models[1].strenghts.cpu().numpy()
# actual_dynamics_mnist = recorded_models[0].history['weights']['W1']
# actual_dynamics_reg_mnist = recorded_models[1].history['weights']['W1']
# actual_dynamics_noise_mnist = mnist_models[2].strenghts.cpu().numpy()
w0 = recorded_models[0].init
theoretical_dynamics_reg = theoretical_learning_dynamics(
                                data_train, 
                                data_train, 
                                n_epoch=epochs, lr=lr, var=0, 
                                reg=reg_param, u0 = w0)

# plot simulated dynamics
x_p = np.arange(0, epochs+1, 1)
rangestart = 0
ax1.plot(theoretical_dynamics_reg[:, slices], c='blue', 
         label='Theory ($\gamma = 0$)')
for s in slices:
    ax1.scatter(x_p[rangestart:], actual_dynamics_mnist[rangestart:, s], c='blue', 
                marker='x', label='Actual ($\gamma = 0$)')
    # ax1.scatter(x_p[rangestart:], actual_dynamics_reg_mnist[rangestart:, s], c='orange', 
    #             marker='x', label='Actual ($\gamma = $' + str(reg_param) + ')')
    # ax2.scatter(x_p, actual_dynamics_mnist[:, s], c='blue', 
    #             marker='x', label='Actual ($\sigma^2 = 0$)')
    # ax2.scatter(x_p, actual_dynamics_noise_mnist[:, s], c='darkgreen',
    #             marker='x', label='Actual ($\sigma^2 = $' + str(var_param) + ')')
    
    
# set plot titles and axis labels
ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)
ax1.set_title('Weight decay')
ax2.yaxis.set_label_position('right')
ax2.set_ylabel('MNIST')
plt.show()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\g'
# <>:26: SyntaxWarning: invalid escape sequence '\g'
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# <>:23: SyntaxWarning: invalid escape sequence '\g'
# <>:26: SyntaxWarning: invalid escape sequence '\g'
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_971751/1268316.py:23: SyntaxWarning: invalid escape sequence '\g'
#   label='Theory ($\gamma = 0$)')
# /tmp/ipykernel_971751/1268316.py:26: SyntaxWarning: invalid escape sequence '\g'
#   marker='x', label='Actual ($\gamma = 0$)')
# /tmp/ipykernel_971751/1268316.py:36: SyntaxWarning: invalid escape sequence '\c'
#   ax1.set_ylabel('$w_2 \cdot w_1$', fontsize=15)

# %% [markdown]
# ### Plots for Checking

# %%
plot_2d_projection_with_principal_axes(data_train, labels_train, dim_x=1, dim_y=3)

# %%
plot_2d_projection_with_principal_axes(data_test, labels_test, dim_x=1, dim_y=2)

# %%
# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(data_test)
label_names, labels_numeric = np.unique(labels_test, return_inverse=True)

plt.figure(figsize=(7, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels_numeric, cmap='tab10', alpha=0.7)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Projection of Test Data')
plt.grid(True)

# Matching legend
handles, _ = scatter.legend_elements(prop="colors", alpha=0.7)
plt.legend(handles, label_names, title='Class')
plt.show()
